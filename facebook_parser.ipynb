# %%
pip install git+https://github.com/kevinzg/facebook-scraper.git
# Out:
# Collecting git+https://github.com/kevinzg/facebook-scraper.git
#   Cloning https://github.com/kevinzg/facebook-scraper.git to /private/var/folders/dq/j0g3xb252n7_c5pq4gvm8dqc0000gp/T/pip-req-build-4neyr9c5
#   Running command git clone -q https://github.com/kevinzg/facebook-scraper.git /private/var/folders/dq/j0g3xb252n7_c5pq4gvm8dqc0000gp/T/pip-req-build-4neyr9c5
#   Resolved https://github.com/kevinzg/facebook-scraper.git to commit 08ddfe5785ec0a0729f92241c45419c75dfc72ec
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: dateparser<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from facebook-scraper==0.2.55) (1.0.0)
# Requirement already satisfied: requests-html<0.11.0,>=0.10.0 in /opt/anaconda3/lib/python3.8/site-packages (from facebook-scraper==0.2.55) (0.10.0)
# Collecting demjson3<4.0.0,>=3.0.5
#   Downloading demjson3-3.0.5.tar.gz (132 kB)
#      |████████████████████████████████| 132 kB 459 kB/s eta 0:00:01
# Requirement already satisfied: regex!=2019.02.19 in /opt/anaconda3/lib/python3.8/site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper==0.2.55) (2021.11.2)
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.8/site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper==0.2.55) (2021.3)
# Requirement already satisfied: tzlocal in /opt/anaconda3/lib/python3.8/site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper==0.2.55) (2.1)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.8/site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper==0.2.55) (2.8.2)
# Requirement already satisfied: pyquery in /opt/anaconda3/lib/python3.8/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (1.4.3)
# Requirement already satisfied: pyppeteer>=0.0.14 in /opt/anaconda3/lib/python3.8/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (0.2.5)
# Requirement already satisfied: w3lib in /opt/anaconda3/lib/python3.8/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (1.22.0)
# Requirement already satisfied: bs4 in /opt/anaconda3/lib/python3.8/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (0.0.1)
# Requirement already satisfied: fake-useragent in /opt/anaconda3/lib/python3.8/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (0.1.11)
# Requirement already satisfied: parse in /opt/anaconda3/lib/python3.8/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (1.19.0)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (2.27.1)
# Requirement already satisfied: websockets<9.0,>=8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (8.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (4.62.3)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (8.1.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (1.26.8)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /opt/anaconda3/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (1.4.4)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.8/site-packages (from bs4->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->bs4->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (2.3.1)
# Requirement already satisfied: cssselect>0.7.9 in /opt/anaconda3/lib/python3.8/site-packages (from pyquery->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (1.1.0)
# Requirement already satisfied: lxml>=2.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyquery->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (4.7.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.8/site-packages (from python-dateutil->dateparser<2.0.0,>=1.0.0->facebook-scraper==0.2.55) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook-scraper==0.2.55) (2.0.4)
# Building wheels for collected packages: facebook-scraper, demjson3
#   Building wheel for facebook-scraper (PEP 517) ... done
#   Created wheel for facebook-scraper: filename=facebook_scraper-0.2.55-py3-none-any.whl size=43310 sha256=86abaea6dde698fb9b2d0217c4f7de180bf6354ef2ebb94067a379cb38de0b21
#   Stored in directory: /private/var/folders/dq/j0g3xb252n7_c5pq4gvm8dqc0000gp/T/pip-ephem-wheel-cache-3_bvl0y1/wheels/aa/39/09/742085e70fef89aa192a999628711df1c08cdbf1690b9989f8
#   Building wheel for demjson3 (setup.py) ... done
#   Created wheel for demjson3: filename=demjson3-3.0.5-py3-none-any.whl size=76070 sha256=31fadaa4ee16391474e9f1d9f12381ed8ae998912ac7885810f4f1f7141db899
#   Stored in directory: /Users/harshmeetsingh/Library/Caches/pip/wheels/b9/7f/83/c60451302e62feb81c84a1455e9a42ccf348e6434ce173047b
# Successfully built facebook-scraper demjson3
# Installing collected packages: demjson3, facebook-scraper
#   Attempting uninstall: facebook-scraper
#     Found existing installation: facebook-scraper 0.2.42
#     Uninstalling facebook-scraper-0.2.42:
#       Successfully uninstalled facebook-scraper-0.2.42
# Successfully installed demjson3-3.0.5 facebook-scraper-0.2.55
# Note: you may need to restart the kernel to use updated packages.

# %%
from facebook_scraper import get_posts

# %%
#print(get_posts(group='504775203219096')
#print(k)

# %%
from facebook_scraper import get_posts
 
listposts = []
for post in get_posts("nintendo", pages=1):
    print(post)
    listposts.append(post)
# Out:
# {'post_id': 5149622868455458, 'text': 'A new Kirby-themed physical award is on the way!\nThis handy, reusable bag features Kirby, who looks ready to inhale your books, groceries, or anything else you put in there! Stay Tuned!\nhttp://ninten.do/6182wUD5u\n1,046 Likes163 comments\nHanna Luna\nAshleigh\nNintendo updated their cover photo.\n25 March at 09:07 ·\n1,019 Likes75 comments\nHossain Mohammed Altab\nI like it👌\nLoading...\nTry Again\nCancel\nLoading...\nLoading...\nrequireLazy(["HasteSupportData"],function(m){m.handle({"gkxData":{"5241":{"result":true,"hash":"AT7o1bCQPGpf3ShEedI"},"676920":{"result":false,"hash":"AT497IX4gOFG8gZe2jg"},"708253":{"result":false,"hash":"AT5n4hBL3YTMnQWtU7k"},"996940":{"result":false,"hash":"AT7opYuEGy3sjG1aSqI"},"1263340":{"result":false,"hash":"AT5bwizWgDaFQudmb4I"}}})});requireLazy(["TimeSliceImpl","ServerJS"],function(TimeSlice,ServerJS){(new ServerJS()).handle({"define":[["CometPersistQueryParams",[],{"relative":{},"domain":{}},6231],["BigPipeExperiments",[],{"link_images_to_pagelets":false,"enable_bigpipe_plugins":false},907],["BootloaderConfig",[],{"deferBootloads":false,"jsRetries":[200,500],"jsRetryAbortNum":2,"jsRetryAbortTime":5,"silentDups":false,"hypStep4":false,"phdOn":false,"btCutoffIndex":591},329],["CSSLoaderConfig",[],{"timeout":5000,"modulePrefix":"BLCSS:","loadEventSupported":true},619],["CurrentCommunityInitialData",[],{},490],["CurrentUserInitialData",[],{"ACCOUNT_ID":"0","USER_ID":"0","NAME":"","SHORT_NAME":null,"IS_BUSINESS_PERSON_ACCOUNT":false,"HAS_SECONDARY_BUSINESS_PERSON":false,"IS_FACEBOOK_WORK_ACCOUNT":false,"IS_MESSENGER_ONLY_USER":false,"IS_DEACTIVATED_ALLOWED_ON_MESSENGER":false,"IS_MESSENGER_CALL_GUEST_USER":false,"IS_WORK_MESSENGER_CALL_GUEST_USER":false,"APP_ID":"412378670482","IS_BUSINESS_DOMAIN":false},270],["ErrorDebugHooks",[],{"SnapShotHook":null},185],["ISB",[],{},330],["LSD",[],{"token":"AVqX81C9P08"},323],["MRequestConfig",[],{"dtsg":{"token":"AQEDOBKdHq1pSBE:0:0","valid_for":86400,"expire":1649334771},"dtsg_ag":{"token":"AQz-vrDJbAGzHnMNeGLw6xCJwThyM8mPOSmzV1bh7pT0nOSm:0:0","valid_for":604800,"expire":1649853171},"lsd":"AVqX81C9P08","checkResponseOrigin":true,"checkResponseToken":true,"cleanFinishedRequest":false,"cleanFinishedPrefetchRequests":false,"ajaxResponseToken":{"secret":"Q6oROaw58siYALGtdJ_Unhgjd5eKFq-5","encrypted":"AYlK4xlcn5SNur5ej-9skpiltzfp3kNAXfA_2R3z6BYkuutc-2vC97M2TGkPRqpBNA3Je4VP78MpFtQM5BTqV1enUhHm3rmYcB8W-1xm4zMKgw"}},51],["ServerNonce",[],{"ServerNonce":"SCoyXyqU1SUClZiF4eSRaP"},141],["SiteData",[],{"server_revision":1005306840,"client_revision":1005306840,"tier":"","push_phase":"C3","pkg_cohort":"BP:mtouch_pkg","haste_session":"19088.BP:mtouch_pkg.2.0.0.0.","pr":1,"haste_site":"mobile","manifest_base_uri":"https:\\/\\/static.xx.fbcdn.net","manifest_origin":null,"be_one_ahead":false,"is_rtl":false,"is_comet":false,"is_experimental_tier":false,"is_jit_warmed_up":true,"hsi":"7083467817065568906-0","semr_host_bucket":"6","bl_hash_version":2,"skip_rd_bl":true,"comet_env":0,"wbloks_env":false,"spin":0,"__spin_r":1005306840,"__spin_b":"trunk","__spin_t":1649248371,"vip":"31.13.79.35"},317],["SprinkleConfig",[],{"param_name":"jazoest","version":2,"should_randomize":false},2111],["PromiseUsePolyfillSetImmediateGK",[],{"www_always_use_polyfill_setimmediate":false},2190],["KSConfig",[],{"killed":{"__set":["MOBILIZER_SELF_SERVE_OWNERSHIP_RESOLVER","MLHUB_FLOW_AUTOREFRESH_SEARCH","NEKO_DISABLE_CREATE_FOR_SAP","EO_DISABLE_SYSTEM_SERIAL_NUMBER_FREE_TYPING_IN_CPE_NON_CLIENT","MOBILITY_KILL_OLD_VISIBILITY_POSITION_SETTING","WORKPLACE_DISPLAY_TEXT_EVIDENCE_REPORTING","BUSINESS_INVITE_FLOW_WITH_SELLER_PROFILE","BUY_AT_UI_LINE_DELETE","BUSINESS_GRAPH_SETTING_APP_ASSIGNED_USERS_NEW_API","BUSINESS_GRAPH_SETTING_BU_ASSIGNED_USERS_NEW_API","BUSINESS_GRAPH_SETTING_ESG_ASSIGNED_USERS_NEW_API","BUSINESS_GRAPH_SETTING_PRODUCT_CATALOG_ASSIGNED_USERS_NEW_API","BUSINESS_GRAPH_SETTING_SESG_ASSIGNED_USERS_NEW_API","BUSINESS_GRAPH_SETTING_WABA_ASSIGNED_USERS ...
# {'post_id': 5149622868455458, 'text': '1,019 Likes75 comments\nHossain Mohammed Altab\nI like it👌\nLoading...\nTry Again\nCancel\nLoading...\nLoading...\nrequireLazy(["HasteSupportData"],function(m){m.handle({"gkxData":{"5241":{"result":true,"hash":"AT7o1bCQPGpf3ShEedI"},"676920":{"result":false,"hash":"AT497IX4gOFG8gZe2jg"},"708253":{"result":false,"hash":"AT5n4hBL3YTMnQWtU7k"},"996940":{"result":false,"hash":"AT7opYuEGy3sjG1aSqI"},"1263340":{"result":false,"hash":"AT5bwizWgDaFQudmb4I"}}})});requireLazy(["TimeSliceImpl","ServerJS"],function(TimeSlice,ServerJS){(new ServerJS()).handle({"define":[["CometPersistQueryParams",[],{"relative":{},"domain":{}},6231],["BigPipeExperiments",[],{"link_images_to_pagelets":false,"enable_bigpipe_plugins":false},907],["BootloaderConfig",[],{"deferBootloads":false,"jsRetries":[200,500],"jsRetryAbortNum":2,"jsRetryAbortTime":5,"silentDups":false,"hypStep4":false,"phdOn":false,"btCutoffIndex":591},329],["CSSLoaderConfig",[],{"timeout":5000,"modulePrefix":"BLCSS:","loadEventSupported":true},619],["CurrentCommunityInitialData",[],{},490],["CurrentUserInitialData",[],{"ACCOUNT_ID":"0","USER_ID":"0","NAME":"","SHORT_NAME":null,"IS_BUSINESS_PERSON_ACCOUNT":false,"HAS_SECONDARY_BUSINESS_PERSON":false,"IS_FACEBOOK_WORK_ACCOUNT":false,"IS_MESSENGER_ONLY_USER":false,"IS_DEACTIVATED_ALLOWED_ON_MESSENGER":false,"IS_MESSENGER_CALL_GUEST_USER":false,"IS_WORK_MESSENGER_CALL_GUEST_USER":false,"APP_ID":"412378670482","IS_BUSINESS_DOMAIN":false},270],["ErrorDebugHooks",[],{"SnapShotHook":null},185],["ISB",[],{},330],["LSD",[],{"token":"AVqX81C9P08"},323],["MRequestConfig",[],{"dtsg":{"token":"AQEDOBKdHq1pSBE:0:0","valid_for":86400,"expire":1649334771},"dtsg_ag":{"token":"AQz-vrDJbAGzHnMNeGLw6xCJwThyM8mPOSmzV1bh7pT0nOSm:0:0","valid_for":604800,"expire":1649853171},"lsd":"AVqX81C9P08","checkResponseOrigin":true,"checkResponseToken":true,"cleanFinishedRequest":false,"cleanFinishedPrefetchRequests":false,"ajaxResponseToken":{"secret":"Q6oROaw58siYALGtdJ_Unhgjd5eKFq-5","encrypted":"AYlK4xlcn5SNur5ej-9skpiltzfp3kNAXfA_2R3z6BYkuutc-2vC97M2TGkPRqpBNA3Je4VP78MpFtQM5BTqV1enUhHm3rmYcB8W-1xm4zMKgw"}},51],["ServerNonce",[],{"ServerNonce":"SCoyXyqU1SUClZiF4eSRaP"},141],["SiteData",[],{"server_revision":1005306840,"client_revision":1005306840,"tier":"","push_phase":"C3","pkg_cohort":"BP:mtouch_pkg","haste_session":"19088.BP:mtouch_pkg.2.0.0.0.","pr":1,"haste_site":"mobile","manifest_base_uri":"https:\\/\\/static.xx.fbcdn.net","manifest_origin":null,"be_one_ahead":false,"is_rtl":false,"is_comet":false,"is_experimental_tier":false,"is_jit_warmed_up":true,"hsi":"7083467817065568906-0","semr_host_bucket":"6","bl_hash_version":2,"skip_rd_bl":true,"comet_env":0,"wbloks_env":false,"spin":0,"__spin_r":1005306840,"__spin_b":"trunk","__spin_t":1649248371,"vip":"31.13.79.35"},317],["SprinkleConfig",[],{"param_name":"jazoest","version":2,"should_randomize":false},2111],["PromiseUsePolyfillSetImmediateGK",[],{"www_always_use_polyfill_setimmediate":false},2190],["KSConfig",[],{"killed":{"__set":["MOBILIZER_SELF_SERVE_OWNERSHIP_RESOLVER","MLHUB_FLOW_AUTOREFRESH_SEARCH","NEKO_DISABLE_CREATE_FOR_SAP","EO_DISABLE_SYSTEM_SERIAL_NUMBER_FREE_TYPING_IN_CPE_NON_CLIENT","MOBILITY_KILL_OLD_VISIBILITY_POSITION_SETTING","WORKPLACE_DISPLAY_TEXT_EVIDENCE_REPORTING","BUSINESS_INVITE_FLOW_WITH_SELLER_PROFILE","BUY_AT_UI_LINE_DELETE","BUSINESS_GRAPH_SETTING_APP_ASSIGNED_USERS_NEW_API","BUSINESS_GRAPH_SETTING_BU_ASSIGNED_USERS_NEW_API","BUSINESS_GRAPH_SETTING_ESG_ASSIGNED_USERS_NEW_API","BUSINESS_GRAPH_SETTING_PRODUCT_CATALOG_ASSIGNED_USERS_NEW_API","BUSINESS_GRAPH_SETTING_SESG_ASSIGNED_USERS_NEW_API","BUSINESS_GRAPH_SETTING_WABA_ASSIGNED_USERS_NEW_API","ADS_PLACEMENT_FIX_PUBLISHER_PLATFORMS_MUTATION","FORCE_FETCH_BOOSTED_COMPONENT_AFTER_ADS_CREATION","VIDEO_DIMENSIONS_FROM_PLAYER_IN_UPLOAD_DIALOG","SNIVY_GROUP_BY_EVENT_TRACE_ID_AND_NAME","ADS_STORE_VISITS_METRICS_DEPRECATION","DYNAMIC_ADS_SET_CATALOG_AND_PRODUCT_SET_TOGETHER","AD_DRAFT_ENABLE_SYNCRHONOUS_FRA ...

# %%
listposts[1].keys()
# Out:
# dict_keys(['post_id', 'text', 'post_text', 'shared_text', 'original_text', 'time', 'timestamp', 'image', 'image_lowquality', 'images', 'images_description', 'images_lowquality', 'images_lowquality_description', 'video', 'video_duration_seconds', 'video_height', 'video_id', 'video_quality', 'video_size_MB', 'video_thumbnail', 'video_watches', 'video_width', 'likes', 'comments', 'shares', 'post_url', 'link', 'links', 'user_id', 'username', 'user_url', 'is_live', 'factcheck', 'shared_post_id', 'shared_time', 'shared_user_id', 'shared_username', 'shared_post_url', 'available', 'comments_full', 'reactors', 'w3_fb_url', 'reactions', 'reaction_count', 'with', 'page_id', 'sharers', 'image_id', 'image_ids', 'was_live'])
